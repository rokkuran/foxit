# %%
import pymongo
from pymongo import MongoClient

import pandas as pd

import json
import pprint
pp = pprint.PrettyPrinter(indent=2)

from collections import defaultdict

from surprise import NormalPredictor, SVD, NMF, SlopeOne, CoClustering
from surprise import KNNBasic, KNNWithMeans, KNNWithZScore, KNNBaseline
from surprise import Dataset
from surprise import Reader
from surprise import evaluate
from surprise import accuracy
from surprise.model_selection import cross_validate, train_test_split

# %%
def db_collections(client: MongoClient):
    d = {db: [collection for collection in client[db].list_collection_names()] for db in client.list_database_names()}
    return json.dumps(d)

# %%
def encode_dict(d: dict, encoding='utf-8'):
    a = {k: v.encode(encoding) for k, v in d.items() if type(v)==str}
    b = {k: v for k, v in d.items() if type(v)!=str}
    return {**a, **b}

# %%
client = MongoClient()
print(db_collections(client))
# Out:
# {"admin": ["system.version"], "config": ["system.sessions"], "kitsu": ["users", "anime", "library"], "local": ["startup_log"], "test": ["library", "anime", "users"]}

# %%
attributes = ['user_id', 'media_id', 'rating']
data = {k: [] for k in attributes}


collection = client.kitsu.library
cursor = collection.find(
    {"rating": {"$ne": None}}
)

for i, doc in enumerate(cursor):
    x = encode_dict(doc)
    for k in data:
        data[k].append(x[k])


df = pd.DataFrame(data)
df.describe()
# Out:
#             user_id      media_id        rating
# count  27048.000000  27048.000000  27048.000000
# mean     137.236210   4379.675281     15.975451
# std       87.612007   3182.024317      3.998788
# min        2.000000      1.000000      2.000000
# 25%       61.000000   1219.000000     14.000000
# 50%      129.000000   4603.500000     16.000000
# 75%      214.000000   6734.000000     20.000000
# max      299.000000  41204.000000     20.000000

# %%
collection = client.kitsu.anime

cursor = collection.find(
    {},
    {'id': 1, 'slug': 1, '_id': 0}
)

id_slug_map = {}
for i, doc in enumerate(cursor):
    x = encode_dict(doc)
    id_slug_map[x['id']] = x['slug']

id_slug_map
# Out:
# {214: b'gankutsuou',
#  1: b'cowboy-bebop',
#  9: b'initial-d-fourth-stage',
#  161: b'xenosaga-the-animation',
#  17: b'texhnolyze',
#  156: b'ultra-maniac-ova',
#  22: b'neon-genesis-evangelion-death-rebirth',
#  4: b'witch-hunter-robin',
#  36: b'arc-the-lad',
#  45: b'rozen-maiden',
#  178: b'video-girl-ai',
#  38: b'beck',
#  8: b'hungry-heart-wild-striker',
#  5: b'beet-the-vandel-buster',
#  15: b'school-rumble',
#  33: b'angelic-layer',
#  28: b'rurouni-kenshin-ishinshishi-e-no-requiem',
#  23: b'neon-genesis-evangelion-the-end-of-evangelion',
#  25: b'ghost-in-the-shell',
#  11: b'naruto',
#  47: b'azumanga-daioh',
#  154: b'tsubasa-chronicle',
#  168: b'love-hina-christmas-special-silent-eve',
#  29: b'akira',
#  166: b'love-hina',
#  153: b'triangle-heart-sweet-songs-forever',
#  152: b'tokyo-underground',
#  46: b'rozen-maiden-traumend',
#  12: b'one-piece',
#  30: b'hack-sign',
#  35: b'appleseed-movie',
#  85: b'hana-yori-dango',
#  3: b'trigun',
#  42: b'd-n-angel',
#  175: b'speed-grapher',
#  160: b'whistle',
#  162: b'initial-d-first-stage',
#  26: b'rurouni-kenshin-tsuiokuhen',
#  20: b'zipang',
#  150: b'tactics',
#  13: b'prince-of-tennis',
#  157: b'vandread',
#  41: b'chrno-crusade',
#  40: b'chobits',
#  155: b'ultra-maniac',
#  70: b'mobile-suit-gundam-wing-endless-waltz-movie',
#  71: b'after-war-gundam-x',
#  81: b'aishiteruze-baby',
#  61: b'mobile-suit-gundam-0080-war-in-the-pocket',
#  27: b'rurouni-kenshin',
#  163: b'initial-d-second-stage',
#  53: b'full-metal-panic-the-second-raid',
#  31: b'aa-megami-sama-tv',
#  88: b'bakuretsu-tenshi',
#  80: b'air-movie',
#  205: b'air-master',
#  84: b'boys-be',
#  170: b'maburaho',
#  113: b'gunslinger-girl',
#  104: b'futakoi',
#  164: b'initial-d-third-stage',
#  159: b'escaflowne',
#  97: b'el-hazard-2-the-magnificent-world',
#  95: b'el-hazard-the-wanderers',
#  218: b'gravitation',
#  10: b'monster',
#  34: b'ai-yori-aoshi',
#  128: b'blood',
#  68: b'mobile-suit-victory-gundam',
#  118: b'hunter-x-hunter-greed-island-final',
#  105: b'futakoi-alternative',
#  101: b'full-moon-wo-sagashite',
#  147: b'shingetsutan-tsukihime',
#  7: b'honey-and-clover',
#  141: b'power-stone',
#  142: b'princess-mononoke',
#  130: b'solty-rei',
#  224: b'inuyasha',
#  122: b'kanon-2006',
#  2: b'cowboy-bebop-tengoku-no-tobira',
#  14: b'ring-ni-kakero-1',
#  219: b'agatha-christie-no-meitantei-poirot-to-marple',
#  215: b'genshiken',
#  132: b'shaman-king',
#  82: b'akazukin-chacha',
#  39: b'blue-gender',
#  115: b'hunter-x-hunter',
#  201: b'elfen-lied',
#  232: b'ikkitousen',
#  32: b'tenshi-kinryouku',
#  92: b'uchuu-no-stellvia',
#  228: b'jungle-wa-itsumo-hare-nochi-guu',
#  221: b'groove-adventure-rave',
#  124: b'kono-minikuku-mo-utsukushii-sekai',
#  172: b'onegai-teacher',
#  158: b'vandread-the-second-stage',
#  76: b'last-exile',
#  19: b'yakitate-japan',
#  204: b'two-x2-shinobuden',
#  146: b'scryed',
#  174: b'rizelmine',
#  21: b'neon-genesis-evangelion',
#  191: b'pia-carrot-2-dx',
#  18: b'trinity-blood',
#  86: b'ou-dorobou-jing',
#  180: b'yumeria',
#  169: b'love-hina-spring-special',
#  167: b'love-hina-again',
#  44: b'dears',
#  151: b'tenjou-tenge',
#  202: b'flcl',
#  37: b'avenger',
#  198: b'mezzo-dsa',
#  194: b'kidou-senkan-nadesico',
#  58: b'shuffle',
#  63: b'mobile-suit-gundam-0083-stardust-memory',
#  43: b'da-capo',
#  200: b'dragon-ball-gt',
#  56: b'mahou-shoujo-lyrical-nanoha',
#  207: b'cardcaptor-sakura',
#  229: b'jungle-wa-itsumo-hare-nochi-guu-deluxe',
#  120: b'kamikaze-kaitou-jeanne',
#  173: b'onegai-twins',
#  231: b'voices-of-a-distant-star',
#  51: b'full-metal-panic',
#  83: b'ayashi-no-ceres',
#  143: b'rahxephon',
#  119: b'jinki-extend-ova',
#  185: b'r-o-d',
#  107: b'gate-keepers-21',
#  116: b'hunter-x-hunter-ova',
#  123: b'kareshi-kanojo-no-jijou',
#  176: b'spirited-away',
#  182: b'lodoss-tou-senki-eiyuu-kishi-den',
#  213: b'flame-of-recca',
#  117: b'hunter-x-hunter-greed-island',
#  186: b'ranma-nettou-hen',
#  60: b'mobile-suit-gundam-the-08th-ms-team',
#  49: b'black-cat',
#  48: b'basilisk-kouga-ninpou-chou',
#  188: b'project-a-ko',
#  181: b'samurai-champloo',
#  208: b'daa-daa-daa',
#  171: b'macross-zero',
#  59: b'mobile-suit-gundam',
#  177: b'tenshi-na-konamaiki',
#  55: b'soukyuu-no-fafner-dead-aggressor',
#  100: b'fullmetal-alchemist',
#  87: b'ou-dorobou-jing-in-seventh-heaven',
#  99: b'fruits-basket',
#  96: b'el-hazard-the-magnificent-world',
#  52: b'full-metal-panic-fumoffu',
#  64: b'mobile-suit-zeta-gundam',
#  69: b'mobile-suit-gundam-wing',
#  75: b'mobile-fighter-g-gundam',
#  91: b'cosprayers',
#  79: b'shin-shirayuki-hime-densetsu-pretear',
#  110: b'saiyuki-reload-gunlock',
#  62: b'mobile-suit-gundam-the-08th-ms-team-miller-s-report',
#  106: b'gate-keepers',
#  65: b'mobile-suit-gundam-zz',
#  98: b'final-approach',
#  66: b'mobile-suit-gundam-char-s-counterattack',
#  203: b'jigoku-shoujo',
#  102: b'fushigi-yuugi',
#  67: b'mobile-suit-gundam-f91',
#  6: b'eyeshield-21',
#  93: b'sakigake-cromartie-koukou',
#  199: b'dragon-ball',
#  210: b'detective-conan',
#  184: b'r-o-d-ova',
#  109: b'saiyuki-reload',
#  129: b're-cutie-honey',
#  24: b'berserk',
#  136: b'maria-sama-ga-miteru-specials',
#  209: b'dan-doh',
#  195: b'kidou-senkan-nadesico-the-prince-of-darkness',
#  220: b'great-teacher-onizuka',
#  112: b'green-green',
#  139: b'peace-maker-kurogane',
#  127: b'loveless',
#  222: b'harukanaru-toki-no-naka-de-hachiyou-shou',
#  16: b'desert-punk',
#  183: b'lodoss-tou-senki',
#  217: b'gokusen',
#  111: b'getbackers',
#  133: b'x-1999',
#  216: b'girls-bravo-first-season',
#  206: b'asagiri-no-miko',
#  148: b'slam-dunk',
#  126: b'kita-e-diamond-dust-drops',
#  140: b'pita-ten',
#  74: b'turn-a-gundam',
#  211: b'e-s-otherwise',
#  225: b'konjiki-no-gash-bell',
#  233: b'hitsuji-no-uta',
#  50: b'cluster-edge',
#  73: b'mobile-suit-gundam-seed-destiny',
#  72: b'mobile-suit-gundam-seed',
#  134: b'x',
#  103: b'fushigi-yuugi-eikoden',
#  131: b'juuni-kokuki',
#  57: b'mahou-shoujo-lyrical-nanoha-a-s',
#  90: b'corrector-yui',
#  125: b'kimi-ga-nozomu-eien',
#  192: b'pia-carrot-the-movie',
#  226: b'kyou-kara-maou',
#  89: b'chuuka-ichiban',
#  144: b'samurai-7',
#  94: b'el-hazard-the-alternative-world',
#  108: b'saiyuki',
#  145: b'scrapped-princess',
#  212: b'eureka-seven',
#  137: b'boukyaku-no-senritsu',
#  77: b'mai-hime',
#  223: b'ichigo-100-special-jump-festa-2004',
#  121: b'kannazuki-no-miko',
#  114: b'hikaru-no-go',
#  230: b'jungle-wa-itsumo-hare-nochi-guu-final',
#  135: b'mahou-sensei-negima',
#  78: b'mai-otome',
#  138: b'now-and-then-here-and-there',
#  149: b'strange-dawn',
#  227: b'madlax',
#  54: b'gakuen-alice',
#  236: b'happy-lesson-advance',
#  248: b'mahou-tsukai-ni-taisetsu-na-koto',
#  249: b'kiddy-grade',
#  263: b'bakuten-shoot-beyblade',
#  242: b'gungrave',
#  245: b'hellsing',
#  241: b'gunparade-march-arata-naru-kougunka',
#  238: b'hajime-no-ippo',
#  247: b'noir',
#  239: b'hajime-no-ippo-champion-road',
#  246: b'gad-guard',
#  253: b'viewtiful-joe',
#  240: b'hajime-no-ippo-mashiba-vs-kimura',
#  257: b'angel-heart',
#  243: b'golden-boy',
#  256: b'akane-maniax',
#  250: b'love-love',
#  254: b'kousetsu-hyaku-monogatari',
#  255: b'animal-yokochou',
#  265: b'seikai-no-monshou',
#  273: b'hack-legend-of-the-twilight',
#  251: b'mahoromatic',
#  269: b'divergence-eve',
#  275: b'cinderella-boy',
#  276: b'mirai-shounen-conan',
#  280: b'love-pheromone',
#  261: b'b-tx',
#  288: b'najica-blitz-tactics',
#  289: b'paradise-kiss',
#  277: b'aa-megami-sama-chichaitte-koto-wa-benri-da-ne',
#  332: b'fake',
#  284: b'xiao-qian',
#  286: b'happy-world',
#  282: b'ace-wo-nerae-final-stage',
#  260: b'argento-soma',
#  342: b'bannou-bunka-neko-musume-1998',
#  301: b'marmalade-boy',
#  267: b'dear-boys',
#  305: b'rose-of-versailles',
#  302: b'matantei-loki-ragnarok',
#  330: b'memories-off-3-5-omoide-no-kanata-e',
#  304: b'psychic-academy',
#  334: b'akazukin-chacha-ova',
#  338: b'cardcaptor-sakura-the-movie',
#  325: b'iriya-no-sora-ufo-no-natsu',
#  312: b'eikoku-koi-monogatari-emma',
#  323: b'fate-stay-night',
#  307: b'shura-no-toki',
#  341: b'bannou-bunka-neko-musume-dash',
#  324: b'bokusatsu-tenshi-dokuro-chan',
#  320: b'ojamajo-doremi-dokkaan',
#  329: b'memories-off-2nd',
#  234: b'happy-lesson',
#  314: b'wild-arms-twilight-venom',
#  336: b'boogiepop-phantom',
#  297: b'midori-no-hibi',
#  306: b'serial-experiments-lain',
#  333: b'agent-aika',
#  235: b'happy-lesson-tv',
#  294: b'puchi-puri-yuushi',
#  299: b'doki-doki-densetsu-mahoujin-guru-guru',
#  290: b'paranoia-agent',
#  340: b'bannou-bunka-neko-musume',
#  252: b'mahoromatic-2',
#  268: b'di-gi-charat',
#  259: b'area-88-tv',
#  237: b'happy-lesson-the-final',
#  266: b'da-capo-second-season',
#  262: b'baki-the-grappler',
#  258: b'akage-no-anne',
#  244: b'bleach',
#  270: b'divergence-eve-2-misaki-chronicles',
#  283: b'ace-wo-nerae-1979',
#  281: b'ace-wo-nerae',
#  264: b'comic-party',
#  328: b'memories-off',
#  292: b'peach-girl',
#  271: b'dragon-drive',
#  339: b'cardcaptor-sakura-movie-2-the-sealed-card',
#  315: b'binzume-yousei',
#  308: b'spiral-suiri-no-kizuna',
#  300: b'mama-wa-shougaku-4-nensei',
#  303: b'ginyuu-mokushiroku-meine-liebe',
#  293: b'petshop-of-horrors',
#  291: b'mobile-police-patlabor',
#  318: b'ojamajo-doremi-sharp',
#  295: b'piano',
#  309: b'starship-operators',
#  279: b'zettai-shounen',
#  311: b'futatsu-no-spica',
#  298: b'mahoujin-guru-guru',
#  331: b'gallery-fake',
#  272: b'grenadier-hohoemi-no-senshi',
#  278: b'abashiri-ikka',
#  313: b'w-wish',
#  326: b'i-ll-ckbc',
#  321: b'ultimate-girls',
#  274: b'hack-liminality',
#  319: b'motto-ojamajo-doremi',
#  337: b'burn-up-excess',
#  322: b'shakugan-no-shana',
#  310: b'tsukuyomi-moon-phase',
#  316: b'magical-canan',
#  296: b'planetes',
#  317: b'ojamajo-doremi',
#  327: b'himiko-den',
#  366: b'seikai-no-senki-special',
#  368: b'rurouni-kenshin-seisouhen',
#  345: b'ex-driver-the-movie',
#  362: b'gantz-2nd-stage',
#  359: b'yu-yu-hakusho',
#  398: b'legend-of-lemnear',
#  386: b'stratos-4-ova',
#  351: b'gantz',
#  373: b'buzzer-beater',
#  372: b'blood-the-last-vampire',
#  389: b'shiritsu-araiso-koutougakkou-seitokai-shikkoubu',
#  363: b'seikai-no-senki',
#  529: b'nausicaa-of-the-valley-of-the-wind',
#  394: b'fullmetal-alchemist-the-conqueror-of-shamballa',
#  344: b'ex-driver',
#  531: b'rean-no-tsubasa',
#  406: b'onegai-teacher-ova',
#  393: b'kaleido-star-legend-of-phoenix-layla-hamilton-monogatari',
#  369: b'otogi-jushi-akazukin-ova',
#  380: b'porco-rosso',
#  533: b'kagihime-monogatari-eikyuu-alice-rinbukyoku',
#  414: b'inuyasha-tenka-hadou-no-ken',
#  397: b'the-place-promised-in-our-early-days',
#  403: b'shoujo-kakumei-utena',
#  401: b'phantom-the-animation',
#  422: b'one-piece-nejimaki-jima-no-daibouken',
#  424: b'one-piece-dead-end-no-bouken',
#  538: b'sexy-commando-gaiden-sugoiyo-masaru-san',
#  415: b'inuyasha-toki-wo-koeru-omoi',
#  425: b'one-piece-norowareta-seiken',
#  432: b'okusama-wa-joshikousei-2005',
#  423: b'one-piece-chinjuujima-no-chopper-oukoku',
#  426: b'one-piece-omatsuri-danshaku-to-himitsu-no-shima',
#  545: b'kage-kara-mamoru',
#  527: b'jin-roh-the-wolf-brigade',
#  408: b'tales-of-eternia',
#  534: b'grave-of-the-fireflies',
#  451: b'paniponi-dash',
#  435: b'tide-line-blue',
#  441: b'the-law-of-ueki',
#  537: b'honoo-no-labyrinth',
#  399: b'magic-knight-rayearth',
#  420: b'buttobi-cpu',
#  479: b'marmalade-boy-movie',
#  405: b'naruto-the-movie-ninja-clash-in-the-land-of-snow',
#  562: b'otogi-jushi-akazukin',
#  343: b'elfen-lied-special',
#  530: b'saber-marionette-j',
#  587: b'legend-of-basara',
#  413: b'inuyasha-kagami-no-naka-no-mugenjo',
#  378: b'mars-of-destruction',
#  578: b'shichinin-no-nana',
#  535: b'battle-programmer-shirase',
#  585: b'mahoromatic-summer-special',
#  594: b'haunted-junction',
#  541: b'ayakashi-japanese-classic-horror',
#  591: b'iketeru-futari',
#  618: b'refrain-blue',
#  622: b'tenbatsu-angel-rabbie',
#  411: b'tenjou-tenge-the-ultimate-fight',
#  365: b'seikai-no-senki-iii',
#  427: b'one-piece-karakurijou-no-mecha-kyohei',
#  348: b'fushigi-yuugi-ova-2',
#  579: b'mouse',
#  595: b'harukanaru-toki-no-naka-de-ajisai-yumegatari',
#  346: b'excel-saga',
#  431: b'karin',
#  590: b'jubei-chan-the-ninja-girl-2',
#  613: b'kujibiki-unbalance',
#  560: b'tenshi-ni-narumon',
#  602: b'galaxy-angel-3-specials',
#  407: b'maria-sama-ga-miteru-haru-specials',
#  606: b'azumanga-daioh-the-very-short-movie',
#  558: b'futari-wa-precure',
#  607: b'denshin-mamotte-shugogetten',
#  605: b'touhai-densetsu-akagi-yami-ni-maiorita-tensai',
#  374: b'tantei-gakuen-q',
#  400: b'perfect-blue',
#  412: b'inu-yasha-fire-on-the-mystic-island',
#  593: b'hikaru-no-go-journey-to-the-north-star-cup',
#  392: b'kaleido-star-arata-naru-tsubasa-extra-stage',
#  349: b'futari-ecchi',
#  409: b'weiss-kreuz-gluhen',
#  568: b'onmyou-tai-senki',
#  410: b'weiss-kreuz',
#  516: b'rahxephon-interlude-her-and-herself-thatness-and-thereness',
#  360: b'escaflowne-a-girl-in-gaea',
#  570: b'nurse-witch-komugi-chan',
#  544: b'ginga-nagareboshi-gin',
#  430: b'ghost-in-the-shell-2-innocence',
#  436: b'macross-plus',
#  421: b'one-piece-2000',
#  517: b'soukyuu-no-fafner-right-of-left',
#  438: b'ginban-kaleidoscope',
#  445: b'saiyuki-requiem',
#  465: b'glass-no-kamen',
#  402: b'rg-veda',
#  528: b'moldiver',
#  555: b'legend-of-duo',
#  481: b'metropolis',
#  554: b'yuugen-kaisha',
#  433: b'to-heart-2',
#  565: b'popotan',
#  557: b'ko-seiki-beast-sanjuushi',
#  361: b'ai-yori-aoshi-enishi',
#  559: b'fancy-lala',
#  556: b'cat-soup',
#  523: b'tetsuwan-birdy',
#  566: b'platonic-chain',
#  581: b'mamotte-shugogetten',
#  589: b'jubei-chan-the-ninja-girl',
#  569: b'okusama-wa-mahou-shoujo',
#  567: b'petopeto-san',
#  564: b'saikano-another-love-song',
#  580: b'moekan-the-animation',
#  571: b'nurse-angel-ririka-sos',
#  536: b'kogepan',
#  532: b'magikano',
#  507: b'yu-gi-oh',
#  549: b'naruto-takigakure-no-shitou-ore-ga-eiyuu-dattebayo',
#  592: b'honey-and-clover-specials',
#  586: b'mahoromatic-end-year-special',
#  563: b'sakura-taisen-katsudou-shashin',
#  583: b'mahou-tsukai-tai-ova',
#  611: b'kashimashi-girl-meets-girl-ova',
#  588: b'koi-kaze',
#  597: b'hanaukyou-maid-tai-la-verite',
#  364: b'seikai-no-senki-ii',
#  598: b'gunsmith-cats',
#  437: b'hotori-tada-saiwai-wo-koinegau',
#  610: b'jojo-s-bizarre-adventure',
#  419: b'mushishi',
#  522: b'steamboy',
#  575: b'mermaid-forest',
#  612: b'koi-koi-7',
#  616: b'mai-hime-specials',
#  428: b'one-piece-taose-kaizoku-ganzack',
#  561: b'kazemakase-tsukikage-ran',
#  603: b'galaxy-angel-4',
#  576: b'night-walker-mayonaka-no-tantei',
#  513: b'steel-angel-kurumi-zero',
#  577: b'natsuiro-no-sunadokei',
#  552: b'the-cat-returns',
#  439: b'aria-the-animation',
#  442: b'yu-gi-oh-duel-monsters',
#  391: b'kaleido-star',
#  574: b'ninja-gaiden',
#  572: b'juubee-ninpuuchou',
#  404: b'shoujo-kakumei-utena-adolescence-mokushiroku',
#  446: b'damekko-doubutsu',
#  469: b'kakyuusei-2-hitomi-no-naka-no-shoujotachi',
#  418: b'gokujou-seitokai',
#  396: b'iria-zeiram-the-animation',
#  450: b'kamichu-specials',
#  573: b'juubee-ninpuuchou-ryuuhougyoku-hen',
#  449: b'ichigo-mashimaro',
#  584: b'mahou-tsukai-tai',
#  453: b'armitage-iii-dual-matrix',
#  456: b'kamui-no-ken',
#  460: b'doraemon-1979',
#  499: b'tenchi-muyo-ryo-ohki-2',
#  443: b'yu-gi-oh-duel-monsters-gx',
#  476: b'school-rumble-ichi-gakki-hoshuu',
#  495: b'slayers-the-motion-picture',
#  440: b'sousei-no-aquarion',
#  458: b'haja-taisei-dangaiou',
#  472: b'laputa-castle-in-the-sky',
#  462: b'eien-no-aselia',
#  553: b'jinzou-ningen-kikaider-the-animation',
#  447: b'kino-no-tabi-the-beautiful-world',
#  497: b'tenchi-in-tokyo',
#  488: b'saikano',
#  471: b'kiki-s-delivery-service',
#  489: b'bishoujo-senshi-sailor-moon',
#  526: b'musekinin-kanchou-tylor',
#  500: b'tenchi-muyo-ryo-ohki-3',
#  455: b'bakuretsu-hunters-ova',
#  504: b'wind-a-breath-of-heart-2004',
#  467: b'hamtaro',
#  478: b'mahoraba-heartful-days',
#  508: b'baki-the-grappler-ii',
#  490: b'bishoujo-senshi-sailor-moon-r-the-movie',
#  464: b'fushigiboshi-no-futagohime-gyu',
#  525: b'bubblegum-crisis-tokyo-2040',
#  434: b'to-heart',
#  547: b'popolocrois',
#  543: b'itsudatte-my-santa',
#  502: b'venus-wars',
#  550: b'x-ova',
#  540: b'whisper-of-the-heart',
#  548: b'mugen-no-ryvius',
#  475: b'keroro-gunsou',
#  494: b'slayers-next',
#  498: b'tenchi-muyo-ryo-ohki',
#  473: b'le-portrait-de-petit-cossette',
#  515: b'major-s2',
#  521: b'puni-puni-poemii',
#  416: b'hack-gift',
#  520: b'dna',
#  483: b'onegai-twins-ova',
#  477: b'mahou-no-princess-minky-momo',
#  582: b'major-s1',
#  459: b'demon-city-shinjuku',
#  352: b'gilgamesh',
#  470: b'kidou-shinsengumi-moeyo-ken-tv',
#  454: b'armitage-iii-polymatrix',
#  503: b'wandaba-style',
#  551: b'chibits',
#  505: b'wind-a-breath-of-heart-ova',
#  496: b'tekken-the-motion-picture',
#  487: b'pokemon-the-first-movie',
#  357: b'suzuka',
#  448: b'girls-bravo-second-season',
#  355: b'capeta',
#  514: b'steel-angel-kurumi-encore',
#  482: b'my-neighbor-totoro',
#  524: b'the-big-o',
#  546: b'amaenaide-yo',
#  511: b'steel-angel-kurumi',
#  485: b'boku-no-chikyuu-wo-mamotte',
#  444: b'kurau-phantom-memory',
#  350: b'galaxy-angel',
#  493: b'slayers',
#  356: b'karas',
#  388: b'dirty-pair',
#  492: b'sensei-no-ojikan-doki-doki-school-hours',
#  457: b'yami-to-boushi-to-hon-no-tabibito',
#  377: b'kore-ga-watashi-no-goshujin-sama',
#  519: b'sakura-taisen-le-nouveau-paris',
#  542: b'hanbun-no-tsuki-ga-noboru-sora',
#  371: b'bastard',
#  501: b'vampire-hunter-d-bloodlust',
#  510: b'yami-no-matsuei',
#  429: b'ghost-in-the-shell-stand-alone-complex',
#  370: b'hanaukyou-maid-tai',
#  367: b'outlaw-star-pilot',
#  512: b'steel-angel-kurumi-2',
#  353: b'h2',
#  452: b'gedou-otometai',
#  509: b'digimon-adventure',
#  382: b'ranma-chuugoku-nekonron-daikessen-okite-yaburi-no-gekitou-hen',
#  383: b'samurai-deeper-kyou',
#  385: b'stratos-4',
#  381: b'ragnarok',
#  486: b'pokemon',
#  358: b'tales-of-phantasia-the-animation',
#  518: b'sakura-taisen',
#  632: b'yawara',
#  417: b'fantastic-children',
#  619: b'sentimental-journey',
#  506: b'wonderful-days',
#  539: b'noein-mou-hitori-no-kimi-e',
#  480: b'mermaid-melody-pichi-pichi-pitch',
#  617: b'one-kagayaku-kisetsu-e',
#  384: b'spriggan',
#  375: b'final-fantasy-vii-last-order',
#  600: b'galaxy-angel-z',
#  624: b'tenshi-no-shippo-specials',
#  623: b'tenshi-no-shippo',
#  636: b'canvas-sepia-iro-no-motif',
#  601: b'galaxy-angel-3',
#  621: b'shadow-skill-1996',
#  639: b'cosprayers-the-movie',
#  379: b'tonari-no-yamada-kun',
#  634: b'burn-up-scramble',
#  609: b'fullmetal-alchemist-reflections',
#  643: b'mujin-wakusei-survive',
#  387: b'stratos-4-advance',
#  627: b'to-heart-remember-my-memories-specials',
#  625: b'tenshi-no-shippo-chu',
#  376: b'gun-x-sword',
#  630: b'uta-kata-special',
#  615: b'lemon-angel-project',
#  620: b'shadow-skill-eigi',
#  631: b'kyuuketsuki-miyu-ova',
#  395: b'howl-s-moving-castle',
#  646: b'zoids-genesis',
#  648: b'yume-de-aetara-tv',
#  645: b'uchuu-senkan-yamato-movie',
#  596: b'tsuki-wa-higashi-ni-hi-wa-nishi-ni-operation-sanctuary',
#  629: b'uta-kata',
#  640: b'comic-party-revolution',
#  637: b'tenchi-universe',
#  614: b'lamune',
#  604: b'air-in-summer',
#  608: b'elf-ban-kakyuusei',
#  354: b'haibane-renmei',
#  628: b'tokyo-mew-mew',
#  468: b'i-my-me-strawberry-eggs',
#  390: b'final-fantasy',
#  347: b'fushigi-yuugi-ova',
#  638: b'kanon-kazahana',
#  466: b'gravitation-lyrics-of-love',
#  463: b'fatal-fury-the-motion-picture',
#  491: b'bishoujo-senshi-sailor-moon-s',
#  474: b'hajimari-no-boukenshatachi-legend-of-crystania',
#  461: b'dragon-ball-movie-1-shen-long-no-densetsu',
#  484: b'otogizoushi',
#  647: b'high-school-kimengumi',
#  626: b'to-heart-remember-my-memories',
#  635: b'canvas-2-niji-iro-no-sketch',
#  644: b'rec',
#  642: b'patapata-hikousen-no-bouken',
#  641: b'comic-party-specials',
#  661: b'kizuna-koi-no-kara-sawagi',
#  690: b'burn-up-w',
#  652: b'candy-candy-movie',
#  657: b'houkago-no-shokuinshitsu',
#  693: b'tenamonya-voyagers',
#  710: b'mahoujin-guru-guru-movie',
#  654: b'first-kiss-monogatari',
#  729: b'initial-d-extra-stage',
#  702: b'pugyuru',
#  674: b'fish-in-the-trap',
#  707: b'ranma-kessen-tougenkyou-hanayomewo-torimodose',
#  689: b'burn-up',
#  656: b'hiatari-ryoukou',
#  655: b'kingyo-chuuihou',
#  781: b'green-green-ova',
#  752: b'gakuen-heaven',
#  660: b'kizuna',
#  673: b'bomberman-jetters',
#  709: b'onii-sama-e',
#  765: b'mobile-suit-gundam-seed-msv-astray',
#  717: b'android-ana-maico-2010',
#  769: b'slayers-great',
#  714: b'niea-under-7',
#  746: b'colorful',
#  678: b'school-days-ona',
#  708: b'xxxholic-manatsu-no-yoru-no-yume',
#  669: b'haru-wo-daiteita',
#  679: b'kaze-wo-mita-shounen',
#  747: b'ushio-to-tora',
#  685: b'zoids',
#  667: b'trouble-chocolate',
#  686: b'zoids-shin-seiki-zero',
#  738: b'choujuushin-gravion',
#  777: b'nana',
#  805: b'dragon-ball-z-movie-12-fukkatsu-no-fusion-goku-to-vegeta',
#  744: b'samurai-spirits-2',
#  798: b'dragon-ball-z-movie-05-tobikkiri-no-saikyou-tai-saikyou',
#  761: b'digimon-savers',
#  779: b'simoun',
#  770: b'slayers-return',
#  682: b'tenjou-tenge-the-past-chapter',
#  745: b'narue-no-sekai',
#  775: b'mind-game',
#  787: b'candidate-for-goddess-ova',
#  772: b'mahou-shoujo-tai-arusu',
#  671: b'nanami-chan',
#  726: b'boku-wa-imouto-ni-koi-wo-suru',
#  801: b'dragon-ball-z-movie-08-moetsukiro-nessen-ressen-chou-gekisen',
#  758: b'utawarerumono',
#  754: b'gokinjo-monogatari',
#  687: b'cosprayers-specials',
#  712: b'yomigaeru-sora-rescue-wings',
#  778: b'zegapain',
#  753: b'kyou-kara-ore-wa',
#  802: b'dragon-ball-z-movie-09-ginga-girigiri-bucchigiri-no-sugoi-yatsu',
#  771: b'dragon-half',
#  797: b'dragon-ball-z-movie-04-super-saiyajin-da-son-goku',
#  861: b'astro-boy-2003',
#  815: b'ginga-densetsu-weed',
#  800: b'dragon-ball-z-movie-07-kyokugen-battle-sandai-super-saiyajin',
#  817: b'riding-bean',
#  701: b'otaku-no-video',
#  740: b'sister-princess-repure',
#  806: b'dragon-ball-z-movie-13-ryuuken-bakuhatsu-goku-ga-yaraneba-dare-ga-yaru',
#  670: b'true-love-story',
#  791: b'dragon-ball-movie-2-majinjou-no-nemuri-hime',
#  749: b'kiba',
#  681: b'tokyo-godfathers',
#  809: b'geneshaft',
#  716: b'tsubasa-chronicle-tori-kago-no-kuni-no-himegimi',
#  756: b'soul-link',
#  722: b'prince-of-tennis-the-two-samurai-the-first-game',
#  759: b'air-gear',
#  847: b'saiunkoku-monogatari',
#  803: b'dragon-ball-z-movie-10-kiken-na-futari-super-senshi-wa-nemurenai',
#  792: b'dragon-ball-movie-3-makafushigi-daibouken',
#  737: b'platinumhugen-ordian',
#  711: b'hanaukyou-maid-tai-ova',
#  764: b'joshi-kousei',
#  663: b'mar',
#  731: b'guardian-hearts',
#  874: b'dragon-ball-z-saiya-jin-zetsumetsu-keikaku',
#  871: b'ichigo-100-ova',
#  879: b'shinshaku-sengoku-eiyuu-densetsu-sanada-juu-yuushi',
#  785: b'angel-s-egg',
#  878: b'shinshaku-sengoku-eiyuu-densetsu-sanada-juu-yuushi-the-animation',
#  666: b'umi-ga-kikoeru',
#  786: b'amaenaide-yo-katsu',
#  845: b'jyu-oh-sei',
#  697: b'detective-conan-movie-02-the-fourteenth-target',
#  884: b'sin-in-the-rain',
#  840: b'the-third-aoi-hitomi-no-shoujo',
#  889: b'blue-seed-2',
#  876: b'dragon-ball-z-special-1-tatta-hitori-no-saishuu-kessen-freezer-ni-idonda-z-senshi-son-goku-no-chi',
#  774: b'digimon-tamers',
#  706: b'arion',
#  812: b'ninku',
#  757: b'strawberry-panic',
#  826: b'transformers-galaxy-force',
#  789: b'black-lagoon',
#  742: b'kyou-no-go-no-ni',
#  870: b'ground-defence-mao-chan',
#  896: b'tenchi-muyo-in-love',
#  732: b'king-of-fighters-another-day',
#  886: b'bishoujo-senshi-sailor-moon-sailor-stars',
#  833: b'naruto-movie-2-daigekitotsu-maboroshi-no-chiteiiseki-dattebayo',
#  865: b'yokohama-kaidashi-kikou',
#  813: b'fighting-beauty-wulong',
#  895: b'star-ocean-ex',
#  898: b'ranma-special',
#  776: b'street-fighter-ii-v',
#  664: b'bishoujo-senshi-sailor-moon-r',
#  923: b'millennium-actress',
#  919: b'only-yesterday',
#  694: b'nanaka-6-17',
#  914: b'weiss-kreuz-ova',
#  811: b'konjiki-no-gash-bell-mecha-vulkan-no-raishuu',
#  932: b'bronze-zetsuai-since-1989',
#  926: b'kasho-no-tsuki',
#  788: b'pilot-candidate',
#  904: b'chicchana-yukitsukai-sugar-specials',
#  924: b'ouritsu-uchuugun-honneamise-no-tsubasa',
#  755: b'ouran-koukou-host-club',
#  750: b'school-rumble-ni-gakki',
#  790: b'gaogaigar',
#  838: b'the-good-witch-of-the-west',
#  954: b'kishin-houkou-demonbane-tv',
#  705: b'ergo-proxy',
#  942: b'tokyo-juushouden',
#  925: b'patalliro-saiyuki',
#  864: b'dead-leaves',
#  768: b'slayers-gorgeous',
#  748: b'konjiki-no-gash-bell-101-banme-no-mamono',
#  908: b'majutsushi-orphen-revenge',
#  808: b'fullmetal-alchemist-premium-collection',
#  793: b'dragon-ball-movie-4-saikyou-e-no-michi',
#  853: b'love-hina-motoko-s-choice-love-or-the-sword-don-t-cry',
#  783: b'yu-yu-hakusho-meikai-shitou-hen-honoo-no-kizuna',
#  784: b'shin-angyo-onshi',
#  852: b'aria-the-natural',
#  887: b'bishoujo-senshi-sailor-moon-s-kaguya-hime-no-koibito',
#  885: b'prince-of-tennis-the-national-tournament',
#  810: b'himawari-1',
#  751: b'the-melancholy-of-haruhi-suzumiya',
#  880: b'kamisama-kazoku',
#  903: b'le-chevalier-d-eon',
#  872: b'cosplay-complex',
#  907: b'majutsushi-orphen',
#  780: b'aa-megami-sama-sorezore-no-tsubasa-specials',
#  910: b'mirage-of-blaze-rebels-of-the-river-edge',
#  911: b'kaikan-phrase',
#  916: b'eight-clouds-rising',
#  807: b'princess-princess',
#  921: b'yonna-in-the-solitary-fortress',
#  945: b'good-morning-call',
#  881: b'usagi-chan-de-cue',
#  936: b'those-who-hunt-elves-ii',
#  949: b'oruchuban-ebichu',
#  869: b'street-fighter-zero-the-animation',
#  929: b'mizuiro-2003',
#  868: b'getter-robo-armageddon',
#  684: b'bleach-memories-in-the-rain',
#  915: b'the-legend-of-black-heaven',
#  931: b'zetsuai-1989',
#  935: b'those-who-hunt-elves',
#  930: b'mizuiro-jidai',
#  939: b'cello-hiki-no-gauche',
#  696: b'detective-conan-movie-01-the-timed-skyscraper',
#  888: b'blue-seed',
#  877: b'dragon-ball-gt-goku-gaiden-yuuki-no-akashi-wa-suushinchuu',
#  952: b'touch',
#  902: b'sexy-commando-gaiden-sugoiyo-masaru-san-specials',
#  900: b'ranma-chou-musabetsu-kessen-ranma-team-vs-densetsu-no-houou',
#  866: b'yokohama-kaidashi-kikou-quiet-country-cafe',
#  938: b'soultaker',
#  927: b'saint-beast',
#  782: b'yu-yu-hakusho-the-golden-seal',
#  922: b'kumo-no-you-ni-kaze-no-you-ni',
#  713: b'kokoro-toshokan',
#  658: b'interstella-5555-the-5tory-of-the-5ecret-5tar-5ystem',
#  691: b'pale-cocoon',
#  649: b'ai-no-kusabi',
#  762: b'makai-senki-disgaea',
#  843: b'chibi-maruko-chan',
#  763: b'xxxholic',
#  816: b'tokko',
#  863: b'glass-no-kantai-la-legende-du-vent-de-l-univers',
#  842: b'street-fighter-alpha-generations',
#  883: b'dual-parallel-trouble-adventures-special',
#  680: b'rahxephon-pluralitas-concentio',
#  727: b'ginga-eiyuu-densetsu',
#  882: b'dual-parallel-trouble-adventures',
#  913: b'wolf-s-rain-ova',
#  901: b'ranma-super',
#  905: b'full-metal-panic-the-second-raid-wari-to-hima-na-sentaichou-no-ichinichi',
#  906: b'gunnm',
#  947: b'kidou-shinsengumi-moeyo-ken',
#  951: b'mazinkaiser',
#  890: b'uchuu-kaizoku-captain-harlock',
#  875: b'dragon-ball-z-special-2-zetsubou-e-no-hankou-nokosareta-chousenshi-gohan-to-trunks',
#  804: b'dragon-ball-z-movie-11-super-senshi-gekiha-katsu-no-wa-ore-da',
#  899: b'battle-spirits-ryoko-no-ken',
#  718: b'i-s-pure',
#  743: b'narutaru-mukuro-naru-hoshi-tama-taru-ko',
#  741: b'sister-princess',
#  814: b'ike-ina-chuu-takkyuubu',
#  692: b'ginyuu-mokushiroku-meine-liebe-wieder',
#  651: b'baby-love',
#  704: b'shinigami-no-ballad',
#  835: b'shin-getter-robo-vs-neo-getter-robo',
#  725: b'sakura-diaries',
#  794: b'dragon-ball-z-movie-01-ora-no-gohan-wo-kaese',
#  897: b'ranma-ova',
#  700: b'miami-guns',
#  668: b'papa-to-kiss-in-the-dark',
#  941: b'ao-no-6-gou',
#  825: b'transformers-superlink',
#  818: b'gintama',
#  894: b'kanojo-to-kanojo-no-neko',
#  917: b'psychic-force',
#  948: b'mutant-ninja-turtles-superman-legend',
#  912: b'generator-gawl',
#  699: b'gasaraki',
#  672: b'binchou-tan',
#  736: b'chicchana-yukitsukai-sugar',
#  698: b'detective-conan-movie-03-the-last-wizard-of-the-century',
#  950: b'nekojiru-gekijou',
#  796: b'dragon-ball-z-movie-03-chikyuu-marugoto-chou-kessen',
#  683: b'naruto-find-the-crimson-four-leaf-clover',
#  720: b'dragon-ball-z',
#  739: b'bleach-the-sealed-sword-frenzy',
#  695: b'hellsing-ultimate',
#  721: b'prince-of-tennis-atobe-s-gift',
#  724: b'tactical-roar',
#  856: b'crayon-shin-chan',
#  723: b'nanako-kaitai-shinsho',
#  839: b'yume-tsukai',
#  799: b'dragon-ball-z-movie-06-gekitotsu-100-oku-power-no-senshi-tachi',
#  827: b'aura-battler-dunbine',
#  841: b'top-wo-nerae',
#  851: b'virtua-fighter',
#  850: b'shin-chou-kyou-ryo-condor-hero-ii',
#  860: b'romance-of-the-three-kingdoms',
#  823: b'transformers-headmasters',
#  824: b'transformers-victory',
#  719: b'chikyuu-shoujo-arjuna',
#  832: b'witchblade',
#  659: b'vampire-hunter-d',
#  821: b'nurse-witch-komugi-chan-magikarte-z',
#  834: b'appleseed',
#  844: b'magical-nyan-nyan-taruto',
#  846: b'daikuu-maryuu-gaiking',
#  836: b'inukami',
#  688: b'kishin-houkou-demonbane',
#  857: b'hokuto-no-ken',
#  946: b'ippatsu-kiki-musume',
#  858: b'fighting-beauty-wulong-rebirth',
#  703: b'eiken-eikenbu-yori-ai-wo-komete',
#  955: b'combattler-v',
#  944: b'blame',
#  855: b'yoshinaga-san-chi-no-gargoyle',
#  957: b'love-get-chu',
#  956: b'voltes-v',
#  953: b'shakugan-no-shana-specials',
#  933: b'tokyo-babylon',
#  715: b'ghost-in-the-shell-stand-alone-complex-2nd-gig',
#  766: b'kikou-senki-dragonar',
#  828: b'space-runaway-ideon',
#  893: b'aa-megami-sama-specials',
#  892: b'top-wo-nerae-2',
#  795: b'dragon-ball-z-movie-02-konoyo-de-ichiban-tsuyoi-yatsu',
#  873: b'cosplay-complex-extra-identification',
#  820: b'nurse-witch-komugi-chan-special',
#  854: b'smash-hit',
#  822: b'transformers-masterforce',
#  859: b'tsubasa-chronicle-2nd-season',
#  760: b'gunparade-orchestra',
#  650: b'princess-tutu',
#  848: b'heatguy-j',
#  849: b'shin-chou-kyou-ryo-condor-hero',
#  940: b'bobobo-bo-bo-bobo',
#  918: b'princess-arete',
#  958: b'memories-off-5',
#  819: b'ray-the-animation',
#  943: b'tokyo-daigaku-monogatari',
#  920: b'pom-poko',
#  909: b'mirage-of-blaze',
#  891: b'tide-line-blue-special',
#  934: b'taiyou-no-ouji-horus-no-daibouken',
#  837: b'renkin-san-kyuu-magical-pokaan',
#  830: b'dai-mahou-touge',
#  937: b'on-your-mark',
#  728: b'initial-d-battle-stage',
#  829: b'ichigeki-sacchuu-hoihoi-san',
#  773: b'hack-roots',
#  676: b'yuki-no-joou',
#  767: b'slayers-premium',
#  831: b'higurashi-no-naku-koro-ni',
#  964: b'armitage-iii',
#  959: b'sweat-punch',
#  960: b'naruto-finally-a-clash-jounin-vs-genin',
#  963: b'cardcaptor-sakura-leave-it-to-kero-chan',
#  962: b'wizardry',
#  968: b'human-crossing',
#  978: b'oishinbo',
#  975: b'mobile-suit-gundam-i',
#  961: b'netrun-mon-the-movie',
#  976: b'mobile-suit-gundam-ii-soldiers-of-sorrow',
#  973: b'macross',
#  965: b'yukikaze',
#  977: b'mobile-suit-gundam-iii-encounters-in-space',
#  996: b'vandread-gekitouhen',
#  991: b'eikyuu-kazoku',
#  995: b'mermaid-melody-pichi-pichi-pitch-pure',
#  970: b'interlude',
#  966: b'space-pirate-captain-herlock-outside-legend-the-endless-odyssey',
#  980: b'mobile-police-patlabor-the-movie',
#  1006: b'pokemon-advanced-generation-rekkuu-no-houmonsha-deoxys',
#  1004: b'pokemon-mizu-no-miyako-no-mamorigami-latias-to-latios',
#  984: b'shadow-skill-kurudaryuu-kousatsuhou-no-himitsu',
#  985: b'soreyuke-uchuu-senkan-yamamoto-yohko',
#  1012: b'ufo-princess-valkyrie-special',
#  987: b'urda',
#  988: b'shinkon-gattai-godannar',
#  993: b'soul-hunter',
#  1009: b'figure-17',
#  1003: b'pokemon-celebi-toki-wo-koeta-deai',
#  1005: b'pokemon-advanced-generation-nanayo-no-negaiboshi-jirachi',
#  969: b'i-s',
#  1001: b'pokemon-maboroshi-no-pokemon-lugia-bakutan',
#  1020: b'monkey-magic',
#  974: b'macross-do-you-remember-love',
#  1014: b'digimon-frontier',
#  1027: b'tenchi-muyo-the-night-before-the-carnival',
#  997: b'vandread-taidouhen',
#  972: b'kimagure-orange-road',
#  1019: b'medabots',
#  1035: b'e-y-e-s-of-mars',
#  1030: b'choujuushin-gravion-zwei',
#  1034: b'crying-freeman',
#  1026: b'kaze-no-yojimbo',
#  967: b'hikari-to-mizu-no-daphne',
#  1029: b'teito-monogatari',
#  1028: b'tenchi-muyo-ryo-ohki-3-plus-1',
#  1036: b'melty-lancer',
#  1002: b'pokemon-kesshoutou-no-teiou-entei',
#  983: b'samurai-girl-real-bout-high-school',
#  1015: b'tenchi-muyo-gxp',
#  990: b'digital-juice',
#  1025: b'tenchi-muyo-in-love-2-haruka-naru-omoi',
#  994: b'monster-extra',
#  1042: b'maze-bakunetsu-jikuu-tv',
#  1021: b'giniro-no-kami-no-agito',
#  1011: b'ufo-princess-valkyrie-2-juunigatsu-no-yasoukyoku',
#  989: b'shinkon-gattai-godannar-2nd-season',
#  1052: b'slayers-excellent',
#  971: b'kenran-butou-sai-the-mars-daybreak',
#  1007: b'beet-the-vandel-buster-excellion',
#  1039: b'geobreeders-file-x-chibi-neko-dakkan',
#  1023: b'honey-and-clover-ii',
#  1017: b'betterman',
#  1033: b'new-dominion-tank-police',
#  1037: b'zaion-i-wish-you-were-here',
#  986: b'tenchi-muyo-manatsu-no-eve',
#  999: b'handsome-girl',
#  ...}

# %%
reader = Reader(rating_scale=(1, 20))
data = Dataset.load_from_df(df[attributes], reader)

# %%
algos = [KNNBasic(), KNNWithMeans(), KNNWithZScore(), KNNBaseline(), NormalPredictor(), SVD(), NMF(), SlopeOne(), CoClustering()]
for algo in algos:
    cross_validate(algo, data, measures=['RMSE', 'MAE'], cv=5, verbose=True, n_jobs=6)
    print('\n')
# Out:
# Evaluating RMSE, MAE of algorithm KNNBasic on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.7287  3.7440  3.6794  3.6696  3.8713  3.7386  0.0721
# MAE (testset)     2.6715  2.6583  2.6517  2.6356  2.7793  2.6793  0.0513
# Fit time          0.02    0.02    0.02    0.02    0.02    0.02    0.00
# Test time         0.16    0.16    0.16    0.18    0.16    0.16    0.01
#
#
# Evaluating RMSE, MAE of algorithm KNNWithMeans on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.3987  3.3061  3.5155  3.4354  3.3446  3.4001  0.0728
# MAE (testset)     2.3542  2.3431  2.4428  2.3629  2.3255  2.3657  0.0405
# Fit time          0.02    0.02    0.03    0.02    0.03    0.02    0.00
# Test time         0.19    0.20    0.23    0.18    0.17    0.19    0.02
#
#
# Evaluating RMSE, MAE of algorithm KNNWithZScore on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.3936  3.3512  3.3723  3.4020  3.3458  3.3730  0.0223
# MAE (testset)     2.3346  2.3047  2.2985  2.3447  2.2976  2.3160  0.0197
# Fit time          0.03    0.04    0.03    0.03    0.04    0.03    0.00
# Test time         0.21    0.20    0.29    0.23    0.20    0.23    0.03
#
#
# Evaluating RMSE, MAE of algorithm KNNBaseline on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.1958  3.2377  3.3787  3.3464  3.1819  3.2681  0.0799
# MAE (testset)     2.2146  2.2311  2.2971  2.3083  2.2167  2.2536  0.0407
# Fit time          0.04    0.04    0.04    0.04    0.04    0.04    0.00
# Test time         0.24    0.37    0.25    0.29    0.25    0.28    0.05
#
#
# Evaluating RMSE, MAE of algorithm NormalPredictor on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    5.2519  5.2660  5.3591  5.2348  5.3518  5.2927  0.0522
# MAE (testset)     4.1163  4.1221  4.2031  4.0760  4.1824  4.1400  0.0464
# Fit time          0.02    0.02    0.02    0.02    0.02    0.02    0.00
# Test time         0.02    0.02    0.03    0.03    0.02    0.03    0.00
#
#
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.2386  3.1078  3.1969  3.2592  3.2570  3.2119  0.0566
# MAE (testset)     2.3076  2.1987  2.2548  2.2727  2.2554  2.2578  0.0352
# Fit time          1.23    1.19    1.79    1.18    1.71    1.42    0.27
# Test time         0.04    0.03    0.03    0.03    0.03    0.03    0.00
#
#
# Evaluating RMSE, MAE of algorithm NMF on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    9.2760  9.3969  9.4604  9.3724  9.3919  9.3795  0.0596
# MAE (testset)     8.6857  8.8154  8.8521  8.7702  8.8153  8.7878  0.0573
# Fit time          2.27    1.54    1.48    2.16    1.67    1.82    0.33
# Test time         0.03    0.02    0.03    0.02    0.02    0.02    0.00
#
#
# Evaluating RMSE, MAE of algorithm SlopeOne on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.3815  3.4397  3.4471  3.4894  3.4296  3.4375  0.0346
# MAE (testset)     2.3794  2.3983  2.4431  2.4481  2.3931  2.4124  0.0278
# Fit time          0.65    0.58    1.09    0.62    0.98    0.78    0.21
# Test time         0.63    0.67    0.69    0.66    0.70    0.67    0.03
#
#
# Evaluating RMSE, MAE of algorithm CoClustering on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    3.5691  3.5788  3.6690  3.4997  3.5116  3.5656  0.0602
# MAE (testset)     2.4339  2.4714  2.4837  2.4455  2.4390  2.4547  0.0194
# Fit time          0.58    0.55    0.84    0.60    0.79    0.67    0.12
# Test time         0.02    0.02    0.02    0.02    0.02    0.02    0.00

# %%
trainset = data.build_full_trainset()
algo = SVD()
# algo = KNNBasic()
algo.fit(trainset)

# %%
testset = trainset.build_anti_testset()

# %%
predictions = algo.test(testset)

# %%
def get_top_n(predictions, n=10):

    # First map the predictions to each user.
    top_n = defaultdict(list)
    for uid, iid, true_r, est, _ in predictions:
        top_n[uid].append((iid, est))

    # Then sort the predictions for each user and retrieve the k highest ones.
    for uid, user_ratings in top_n.items():
        user_ratings.sort(key=lambda x: x[1], reverse=True)
        top_n[uid] = user_ratings[:n]

    return top_n

# %%
top_n = get_top_n(predictions, n=5)

# Print the recommended items for each user
for uid, user_ratings in top_n.items():
    print("\nuser_id: {}".format(uid))
    for i, (iid, _) in enumerate(user_ratings):
        print("> {}".format(id_slug_map[iid]))
# Out:
# user_id: 7
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'hotarubi-no-mori-e'
# > b'steins-gate-egoistic-poriomania'
# > b'attack-on-titan'
#
# user_id: 3
# > b'darker-than-black'
# > b'attack-on-titan'
# > b'ef-a-tale-of-memories'
# > b'fate-stay-night-unlimited-blade-works'
# > b'fate-zero-2nd-season'
#
# user_id: 2
# > b'code-geass-lelouch-of-the-rebellion'
# > b'toradora'
# > b'hellsing-ultimate'
# > b'baccano-specials'
# > b'the-melancholy-of-haruhi-suzumiya'
#
# user_id: 8
# > b'nausicaa-of-the-valley-of-the-wind'
# > b'porco-rosso'
# > b'rurouni-kenshin-tsuiokuhen'
# > b'chihayafuru'
# > b'kiki-s-delivery-service'
#
# user_id: 28
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
# > b'fullmetal-alchemist-brotherhood'
# > b'nodame-cantabile'
# > b'clannad-after-story'
#
# user_id: 19
# > b'spirited-away'
# > b'howl-s-moving-castle'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'durarara'
# > b'princess-mononoke'
#
# user_id: 39
# > b'paprika'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'durarara'
# > b'btooom'
# > b'hotarubi-no-mori-e'
#
# user_id: 23
# > b'the-girl-who-leapt-through-time'
# > b'summer-wars'
# > b'kanon-2006'
# > b'gyakkyou-burai-kaiji-ultimate-survivor'
# > b'cowboy-bebop'
#
# user_id: 43
# > b'cowboy-bebop'
# > b'spirited-away'
# > b'samurai-champloo'
# > b'angel-beats'
# > b'fullmetal-alchemist-brotherhood'
#
# user_id: 40
# > b'spirited-away'
# > b'paprika'
# > b'angel-beats'
# > b'hotarubi-no-mori-e'
# > b'mahou-shoujo-madoka-magica'
#
# user_id: 38
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'great-teacher-onizuka'
# > b'spirited-away'
# > b'baccano'
#
# user_id: 49
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'last-exile'
# > b'fullmetal-alchemist'
#
# user_id: 25
# > b'cowboy-bebop'
# > b'death-note'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'soul-eater'
# > b'the-girl-who-leapt-through-time'
#
# user_id: 30
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'samurai-champloo'
# > b'darker-than-black'
# > b'trigun-badlands-rumble'
# > b'angel-beats'
#
# user_id: 50
# > b'spirited-away'
# > b'mahou-shoujo-madoka-magica'
# > b'elfen-lied'
# > b'another'
# > b'accel-world'
#
# user_id: 18
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'perfect-blue'
# > b'baccano'
# > b'great-teacher-onizuka'
#
# user_id: 27
# > b'fullmetal-alchemist'
# > b'wolf-children'
# > b'hotarubi-no-mori-e'
# > b'steins-gate-egoistic-poriomania'
# > b'spice-and-wolf'
#
# user_id: 35
# > b'cowboy-bebop'
# > b'samurai-champloo'
# > b'my-neighbor-totoro'
# > b'angel-beats'
# > b'durarara'
#
# user_id: 20
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'last-exile'
# > b'fullmetal-alchemist'
#
# user_id: 44
# > b'monster'
# > b'princess-mononoke'
# > b'cowboy-bebop'
# > b'spice-and-wolf'
# > b'ginga-eiyuu-densetsu'
#
# user_id: 24
# > b'darker-than-black'
# > b'fullmetal-alchemist-brotherhood'
# > b'tengen-toppa-gurren-lagann'
# > b'nichijou'
# > b'code-geass-lelouch-of-the-rebellion'
#
# user_id: 15
# > b'kids-on-the-slope'
# > b'kiki-s-delivery-service'
# > b'great-teacher-onizuka'
# > b'mushishi'
# > b'trigun'
#
# user_id: 11
# > b'beck'
# > b'last-exile'
# > b'spirited-away'
# > b'howl-s-moving-castle'
# > b'laputa-castle-in-the-sky'
#
# user_id: 13
# > b'porco-rosso'
# > b'baccano'
# > b'laputa-castle-in-the-sky'
# > b'aoi-bungaku-series'
# > b'bunny-drop'
#
# user_id: 34
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'spirited-away'
# > b'black-lagoon'
#
# user_id: 36
# > b'baccano'
# > b'cowboy-bebop'
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'the-disappearance-of-haruhi-suzumiya'
#
# user_id: 33
# > b'fullmetal-alchemist'
# > b'princess-mononoke'
# > b'clannad-after-story'
# > b'spirited-away'
# > b'anohana-the-flower-we-saw-that-day'
#
# user_id: 45
# > b'fullmetal-alchemist-brotherhood'
# > b'clannad-after-story'
# > b'clannad'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'the-disappearance-of-haruhi-suzumiya'
#
# user_id: 48
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'fullmetal-alchemist'
# > b'death-note'
# > b'trigun-badlands-rumble'
# > b'angel-beats'
#
# user_id: 17
# > b'cowboy-bebop'
# > b'attack-on-titan'
# > b'one-punch-man'
# > b'redline'
# > b'sakurasou-no-pet-na-kanojo'
#
# user_id: 16
# > b'mushishi'
# > b'k-on-movie'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'monster'
# > b'wolf-children'
#
# user_id: 41
# > b'clannad-after-story'
# > b'great-teacher-onizuka'
# > b'cowboy-bebop'
# > b'monster'
# > b'grave-of-the-fireflies'
#
# user_id: 22
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'tengen-toppa-gurren-lagann'
# > b'steins-gate-egoistic-poriomania'
# > b'spirited-away'
#
# user_id: 14
# > b'fullmetal-alchemist-brotherhood'
# > b'fate-zero-2nd-season'
# > b'monster'
# > b'nodame-cantabile'
# > b'fate-zero'
#
# user_id: 26
# > b'grave-of-the-fireflies'
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
# > b'monster'
# > b'kokoro-connect-michi-random'
#
# user_id: 21
# > b'fullmetal-alchemist-brotherhood'
# > b'mushishi'
# > b'spice-and-wolf-ii'
# > b'ghost-in-the-shell-2-0'
# > b'my-little-monster'
#
# user_id: 31
# > b'btooom'
# > b'sword-of-the-stranger'
# > b'baka-to-test-to-shoukanjuu-ni'
# > b'fate-stay-night-unlimited-blade-works'
# > b'welcome-to-the-n-h-k'
#
# user_id: 46
# > b'porco-rosso'
# > b'rurouni-kenshin-tsuiokuhen'
# > b'fate-zero-2nd-season'
# > b'kuroko-no-basket'
# > b'full-metal-panic-the-second-raid'
#
# user_id: 32
# > b'last-exile'
# > b'yahari-ore-no-seishun-love-comedy-wa-machigatteiru'
# > b'guilty-crown'
# > b'pupa'
# > b'boku-dake-ga-inai-machi'
#
# user_id: 37
# > b'evangelion-2-0-you-can-not-advance'
# > b'kara-no-kyoukai-5-mujun-rasen'
# > b'perfect-blue'
# > b'eureka-seven'
# > b'black-lagoon'
#
# user_id: 12
# > b'steins-gate-egoistic-poriomania'
# > b'evangelion-2-0-you-can-not-advance'
# > b'detective-conan-movie-06-the-phantom-of-baker-street'
# > b'mahou-shoujo-madoka-magica-movie-2-eien-no-monogatari'
# > b'nausicaa-of-the-valley-of-the-wind'
#
# user_id: 60
# > b'steins-gate'
# > b'clannad-after-story'
# > b'fullmetal-alchemist-brotherhood'
# > b'death-note'
# > b'bunny-drop'
#
# user_id: 58
# > b'fullmetal-alchemist-brotherhood'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'monster'
# > b'baccano'
# > b'princess-mononoke'
#
# user_id: 52
# > b'the-girl-who-leapt-through-time'
# > b'elfen-lied'
# > b'redline'
# > b'angel-beats'
# > b'tengen-toppa-gurren-lagann'
#
# user_id: 99
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'steins-gate-egoistic-poriomania'
# > b'angel-beats'
# > b'chihayafuru'
#
# user_id: 65
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'steins-gate'
# > b'the-girl-who-leapt-through-time'
# > b'bakemonogatari'
#
# user_id: 89
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'steins-gate'
# > b'fate-zero-2nd-season'
# > b'the-disappearance-of-haruhi-suzumiya'
#
# user_id: 69
# > b'mahou-shoujo-madoka-magica'
# > b'steins-gate'
# > b'baccano'
# > b'bakemonogatari'
# > b'hellsing-ultimate'
#
# user_id: 98
# > b'fullmetal-alchemist-brotherhood'
# > b'spirited-away'
# > b'baccano'
# > b'steins-gate'
# > b'hotarubi-no-mori-e'
#
# user_id: 71
# > b'fullmetal-alchemist-brotherhood'
# > b'fate-zero-2nd-season'
# > b'monster'
# > b'neon-genesis-evangelion'
# > b'clannad-after-story'
#
# user_id: 51
# > b'kiki-s-delivery-service'
# > b'eden-of-the-east'
# > b'the-girl-who-leapt-through-time'
# > b'fullmetal-alchemist-brotherhood'
# > b'hotarubi-no-mori-e'
#
# user_id: 75
# > b'cowboy-bebop'
# > b'samurai-champloo'
# > b'howl-s-moving-castle'
# > b'kiki-s-delivery-service'
# > b'laputa-castle-in-the-sky'
#
# user_id: 88
# > b'hotarubi-no-mori-e'
# > b'durarara'
# > b'fate-zero-2nd-season'
# > b'baccano'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 54
# > b'fullmetal-alchemist-brotherhood'
# > b'hotarubi-no-mori-e'
# > b'spirited-away'
# > b'kill-la-kill'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 100
# > b'spirited-away'
# > b'death-note'
# > b'eden-of-the-east'
# > b'flcl'
# > b'hotarubi-no-mori-e'
#
# user_id: 79
# > b'gankutsuou'
# > b'ghost-in-the-shell-stand-alone-complex'
# > b'rurouni-kenshin-tsuiokuhen'
# > b'kara-no-kyoukai-5-mujun-rasen'
# > b'princess-mononoke'
#
# user_id: 68
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'clannad-after-story'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'bakemonogatari'
#
# user_id: 90
# > b'cowboy-bebop'
# > b'beck'
# > b'samurai-champloo'
# > b'planetes'
# > b'black-lagoon-the-second-barrage'
#
# user_id: 73
# > b'darker-than-black'
# > b'princess-mononoke'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'sword-of-the-stranger'
#
# user_id: 72
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'the-girl-who-leapt-through-time'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 64
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'cowboy-bebop'
# > b'monster'
# > b'baccano'
#
# user_id: 76
# > b'soul-eater'
# > b'grave-of-the-fireflies'
# > b'serial-experiments-lain'
# > b'tengen-toppa-gurren-lagann'
# > b'welcome-to-the-n-h-k'
#
# user_id: 96
# > b'spirited-away'
# > b'attack-on-titan'
# > b'rurouni-kenshin-tsuiokuhen'
# > b'one-punch-man'
# > b'higurashi-no-naku-koro-ni'
#
# user_id: 67
# > b'howl-s-moving-castle'
# > b'eden-of-the-east'
# > b'eden-of-the-east-movie-i-the-king-of-eden'
# > b'summer-wars'
# > b'deadman-wonderland'
#
# user_id: 57
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'fate-zero'
# > b'tengen-toppa-gurren-lagann'
# > b'princess-mononoke'
#
# user_id: 87
# > b'fullmetal-alchemist'
# > b'samurai-champloo'
# > b'rec'
# > b'the-girl-who-leapt-through-time'
# > b'accel-world'
#
# user_id: 85
# > b'eden-of-the-east'
# > b'princess-mononoke'
# > b'fullmetal-alchemist-brotherhood'
# > b'spice-and-wolf'
# > b'baccano'
#
# user_id: 95
# > b'tengen-toppa-gurren-lagann'
# > b'clannad-after-story'
# > b'evangelion-2-0-you-can-not-advance'
# > b'monster'
# > b'cowboy-bebop'
#
# user_id: 80
# > b'cowboy-bebop'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'soul-eater'
# > b'fullmetal-alchemist-brotherhood'
# > b'jojo-s-bizarre-adventure-2012'
#
# user_id: 53
# > b'porco-rosso'
# > b'howl-s-moving-castle'
# > b'laputa-castle-in-the-sky'
# > b'ergo-proxy'
# > b'trigun-badlands-rumble'
#
# user_id: 81
# > b'beck'
# > b'my-neighbor-totoro'
# > b'the-secret-world-of-arrietty'
# > b'btooom'
# > b'final-fantasy-vii-advent-children-complete'
#
# user_id: 62
# > b'elfen-lied'
# > b'death-note'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'full-metal-panic'
# > b'berserk'
#
# user_id: 77
# > b'code-geass-lelouch-of-the-rebellion'
# > b'hellsing-ultimate'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'mahou-shoujo-madoka-magica'
# > b'fullmetal-alchemist-brotherhood'
#
# user_id: 97
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'baccano'
# > b'steins-gate'
# > b'clannad-after-story'
#
# user_id: 83
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'kiki-s-delivery-service'
# > b'laputa-castle-in-the-sky'
# > b'my-neighbor-totoro'
# > b'paprika'
#
# user_id: 70
# > b'perfect-blue'
# > b'fullmetal-alchemist-brotherhood'
# > b'paprika'
# > b'howl-s-moving-castle'
# > b'k-on-movie'
#
# user_id: 93
# > b'spirited-away'
# > b'monogatari-series-second-season'
# > b'chihayafuru'
# > b'katanagatari'
# > b'psycho-pass'
#
# user_id: 91
# > b'cowboy-bebop'
# > b'fullmetal-alchemist-brotherhood'
# > b'my-little-monster'
# > b'natsume-yuujinchou'
# > b'kids-on-the-slope'
#
# user_id: 63
# > b'code-geass-lelouch-of-the-rebellion'
# > b'claymore'
# > b'attack-on-titan'
# > b'evangelion-2-0-you-can-not-advance'
# > b'death-note'
#
# user_id: 61
# > b'cowboy-bebop'
# > b'hack-sign'
# > b'last-exile'
# > b'samurai-champloo'
# > b'planetes'
#
# user_id: 78
# > b'monster'
# > b'perfect-blue'
# > b'grave-of-the-fireflies'
# > b'kiki-s-delivery-service'
# > b'haibane-renmei'
#
# user_id: 84
# > b'fullmetal-alchemist-brotherhood'
# > b'monster'
# > b'kiki-s-delivery-service'
# > b'steins-gate-egoistic-poriomania'
# > b'baccano-specials'
#
# user_id: 59
# > b'monster'
# > b'fullmetal-alchemist-brotherhood'
# > b'kiki-s-delivery-service'
# > b'attack-on-titan'
# > b'wolf-children'
#
# user_id: 56
# > b'wolf-children'
# > b'sword-of-the-stranger'
# > b'perfect-blue'
# > b'grave-of-the-fireflies'
# > b'kanon-2006'
#
# user_id: 94
# > b'soul-eater'
# > b'perfect-blue'
# > b'monster'
# > b'hellsing-ultimate'
# > b'mahou-shoujo-madoka-magica-movie-3-hangyaku-no-monogatari'
#
# user_id: 55
# > b'fullmetal-alchemist'
# > b'samurai-champloo'
# > b'fate-stay-night'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'code-geass-lelouch-of-the-rebellion-r2'
#
# user_id: 74
# > b'hack-sign'
# > b'shuffle'
# > b'last-exile'
# > b'black-lagoon-the-second-barrage'
# > b'death-note'
#
# user_id: 86
# > b'chihayafuru'
# > b'ghost-in-the-shell-stand-alone-complex-2nd-gig'
# > b'ginga-eiyuu-densetsu'
# > b'nichijou'
# > b'howl-s-moving-castle'
#
# user_id: 82
# > b'laputa-castle-in-the-sky'
# > b'darker-than-black'
# > b'princess-mononoke'
# > b'summer-wars'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 120
# > b'baccano'
# > b'fullmetal-alchemist-brotherhood'
# > b'fate-zero-2nd-season'
# > b'monster'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 139
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'fate-zero-2nd-season'
# > b'tengen-toppa-gurren-lagann'
# > b'baccano'
#
# user_id: 145
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'redline'
# > b'hotarubi-no-mori-e'
# > b'princess-mononoke'
#
# user_id: 118
# > b'monster'
# > b'great-teacher-onizuka'
# > b'clannad-after-story'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'cowboy-bebop'
#
# user_id: 131
# > b'spirited-away'
# > b'samurai-champloo'
# > b'the-girl-who-leapt-through-time'
# > b'fullmetal-alchemist-brotherhood'
# > b'hotarubi-no-mori-e'
#
# user_id: 148
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'tengen-toppa-gurren-lagann'
# > b'steins-gate'
# > b'clannad'
#
# user_id: 153
# > b'spirited-away'
# > b'fullmetal-alchemist-brotherhood'
# > b'wolf-children'
# > b'hotarubi-no-mori-e'
# > b'baccano'
#
# user_id: 127
# > b'eden-of-the-east'
# > b'pokemon'
# > b'neon-genesis-evangelion'
# > b'zero-no-tsukaima'
# > b'ghost-in-the-shell-stand-alone-complex-solid-state-society'
#
# user_id: 173
# > b'black-lagoon-the-second-barrage'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'eden-of-the-east'
# > b'durarara'
#
# user_id: 151
# > b'baccano'
# > b'monster'
# > b'fullmetal-alchemist-brotherhood'
# > b'evangelion-2-0-you-can-not-advance'
# > b'fate-zero-2nd-season'
#
# user_id: 133
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'samurai-champloo'
# > b'black-lagoon'
# > b'black-lagoon-the-second-barrage'
#
# user_id: 101
# > b'black-lagoon'
# > b'black-lagoon-the-second-barrage'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'angel-beats'
#
# user_id: 155
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'samurai-champloo'
# > b'howl-s-moving-castle'
# > b'black-lagoon-roberta-s-blood-trail'
# > b'mirai-nikki-tv'
#
# user_id: 128
# > b'samurai-champloo'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'rurouni-kenshin-tsuiokuhen'
# > b'mahou-shoujo-madoka-magica-movie-1-hajimari-no-monogatari'
#
# user_id: 197
# > b'spirited-away'
# > b'sword-art-online'
# > b'naruto'
# > b'summer-wars'
# > b'attack-on-titan'
#
# user_id: 123
# > b'last-exile'
# > b'the-cat-returns'
# > b'black-lagoon'
# > b'black-lagoon-the-second-barrage'
# > b'black-rock-shooter-ova'
#
# user_id: 105
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'angel-beats'
# > b'the-girl-who-leapt-through-time'
# > b'clannad-after-story'
# > b'welcome-to-the-n-h-k'
#
# user_id: 116
# > b'death-note'
# > b'pokemon'
# > b'shingetsutan-tsukihime'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'kuroko-no-basket'
#
# user_id: 146
# > b'fullmetal-alchemist-brotherhood'
# > b'hotarubi-no-mori-e'
# > b'steins-gate-egoistic-poriomania'
# > b'evangelion-2-0-you-can-not-advance'
# > b'cowboy-bebop'
#
# user_id: 125
# > b'black-lagoon-the-second-barrage'
# > b'death-note'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'black-lagoon-roberta-s-blood-trail'
# > b'durarara'
#
# user_id: 121
# > b'fullmetal-alchemist-brotherhood'
# > b'attack-on-titan'
# > b'baccano'
# > b'fate-zero-2nd-season'
# > b'shinsekai-yori'
#
# user_id: 161
# > b'cowboy-bebop'
# > b'fullmetal-alchemist-brotherhood'
# > b'flcl'
# > b'shigofumi'
# > b'dungeon-ni-deai-wo-motomeru-no-wa-machigatteiru-no-darou-ka'
#
# user_id: 106
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'mahou-shoujo-madoka-magica'
# > b'ichiban-ushiro-no-daimaou'
# > b'darker-than-black-ryuusei-no-gemini'
# > b'fate-zero-2nd-season'
#
# user_id: 110
# > b'eden-of-the-east-movie-i-the-king-of-eden'
# > b'chuunibyou-demo-koi-ga-shitai'
# > b'kill-me-baby'
# > b'clannad-another-world-kyou-chapter'
# > b'eden-of-the-east'
#
# user_id: 169
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'last-exile'
# > b'spirited-away'
#
# user_id: 156
# > b'samurai-champloo'
# > b'sword-art-online'
# > b'fullmetal-alchemist-brotherhood'
# > b'flcl'
# > b'hotarubi-no-mori-e'
#
# user_id: 104
# > b'ghost-in-the-shell-stand-alone-complex'
# > b'cowboy-bebop'
# > b'spirited-away'
# > b'steins-gate-egoistic-poriomania'
# > b'btooom'
#
# user_id: 108
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'darker-than-black'
# > b'the-girl-who-leapt-through-time'
# > b'psycho-pass'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 188
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'angel-beats'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
#
# user_id: 154
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'planetes'
# > b'howl-s-moving-castle'
# > b'my-neighbor-totoro'
# > b'black-lagoon'
#
# user_id: 111
# > b'fullmetal-alchemist-brotherhood'
# > b'fate-zero-2nd-season'
# > b'baccano'
# > b'fate-zero'
# > b'tengen-toppa-gurren-lagann'
#
# user_id: 126
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'spirited-away'
# > b'samurai-champloo'
# > b'code-geass-lelouch-of-the-rebellion-r2'
#
# user_id: 107
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'fullmetal-alchemist'
# > b'samurai-champloo'
# > b'the-cat-returns'
#
# user_id: 192
# > b'steins-gate'
# > b'evangelion-2-0-you-can-not-advance'
# > b'grave-of-the-fireflies'
# > b'perfect-blue'
# > b'fate-zero-2nd-season'
#
# user_id: 189
# > b'princess-mononoke'
# > b'fullmetal-alchemist-brotherhood'
# > b'wolf-children'
# > b'mahou-shoujo-madoka-magica'
# > b'one-punch-man'
#
# user_id: 141
# > b'fullmetal-alchemist-brotherhood'
# > b'bunny-drop'
# > b'eve-no-jikan-movie'
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'steins-gate-fuka-ryouiki-no-deja-vu'
#
# user_id: 150
# > b'steins-gate'
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'nodame-cantabile'
# > b'bunny-drop'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 196
# > b'planetes'
# > b'my-neighbor-totoro'
# > b'rec'
# > b'black-lagoon'
# > b'black-lagoon-the-second-barrage'
#
# user_id: 158
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'kanon-2006'
# > b'neon-genesis-evangelion-the-end-of-evangelion'
# > b'millennium-actress'
# > b'princess-mononoke'
#
# user_id: 152
# > b'steins-gate'
# > b'kara-no-kyoukai-5-mujun-rasen'
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'fate-zero'
# > b'great-teacher-onizuka'
#
# user_id: 160
# > b'blood-c'
# > b'ergo-proxy'
# > b'fullmetal-alchemist-brotherhood'
# > b'neon-genesis-evangelion'
# > b'redline'
#
# user_id: 130
# > b'shinsekai-yori'
# > b'chihayafuru'
# > b'monster'
# > b'fate-stay-night-unlimited-blade-works-tv-episode-0'
# > b'mawaru-penguindrum'
#
# user_id: 164
# > b'baccano-specials'
# > b'baccano'
# > b'wolf-children'
# > b'shinsekai-yori'
# > b'beck'
#
# user_id: 135
# > b'baccano'
# > b'fullmetal-alchemist-the-conqueror-of-shamballa'
# > b'kanon-2006'
# > b'jojo-s-bizarre-adventure-2012'
# > b'tengen-toppa-gurren-lagann'
#
# user_id: 191
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'great-teacher-onizuka'
# > b'fate-zero-2nd-season'
#
# user_id: 142
# > b'fullmetal-alchemist-brotherhood'
# > b'perfect-blue'
# > b'fate-zero-2nd-season'
# > b'welcome-to-the-n-h-k'
# > b'nodame-cantabile'
#
# user_id: 172
# > b'porco-rosso'
# > b'laputa-castle-in-the-sky'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 122
# > b'fullmetal-alchemist-brotherhood'
# > b'hellsing-ultimate'
# > b'clannad-after-story'
# > b'eve-no-jikan-movie'
# > b'elfen-lied'
#
# user_id: 147
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'cowboy-bebop'
# > b'steins-gate-egoistic-poriomania'
# > b'howl-s-moving-castle'
#
# user_id: 178
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'black-lagoon'
# > b'darker-than-black'
# > b'fullmetal-alchemist-brotherhood'
# > b'wolf-children'
#
# user_id: 194
# > b'howl-s-moving-castle'
# > b'my-neighbor-totoro'
# > b'black-lagoon-roberta-s-blood-trail'
# > b'the-girl-who-leapt-through-time'
# > b'mahou-shoujo-madoka-magica'
#
# user_id: 159
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'angel-beats'
# > b'steins-gate-egoistic-poriomania'
# > b'hotarubi-no-mori-e'
#
# user_id: 163
# > b'kiki-s-delivery-service'
# > b'fullmetal-alchemist-brotherhood'
# > b'princess-mononoke'
# > b'attack-on-titan'
# > b'tengen-toppa-gurren-lagann'
#
# user_id: 179
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'bakemonogatari'
# > b'monster'
#
# user_id: 176
# > b'spirited-away'
# > b'steins-gate-egoistic-poriomania'
# > b'monster'
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'mahou-shoujo-madoka-magica'
#
# user_id: 187
# > b'elfen-lied'
# > b'clannad-after-story'
# > b'mahou-shoujo-madoka-magica'
# > b'evangelion-2-0-you-can-not-advance'
# > b'redline'
#
# user_id: 166
# > b'shiki'
# > b'oreimo'
# > b'tengen-toppa-gurren-lagann'
# > b'katekyo-hitman-reborn'
# > b'guilty-crown'
#
# user_id: 143
# > b'samurai-champloo'
# > b'laputa-castle-in-the-sky'
# > b'my-neighbor-totoro'
# > b'black-lagoon'
# > b'black-lagoon-roberta-s-blood-trail'
#
# user_id: 200
# > b'attack-on-titan'
# > b'neon-genesis-evangelion'
# > b'fullmetal-alchemist-brotherhood'
# > b'five-centimeters-per-second'
# > b'psycho-pass'
#
# user_id: 199
# > b'attack-on-titan'
# > b'baccano'
# > b'perfect-blue'
# > b'haibane-renmei'
# > b'kanon-2006'
#
# user_id: 175
# > b'fullmetal-alchemist-brotherhood'
# > b'monster'
# > b'steins-gate-egoistic-poriomania'
# > b'fate-zero-2nd-season'
# > b'fate-zero'
#
# user_id: 170
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'last-exile'
# > b'spirited-away'
#
# user_id: 168
# > b'shiki'
# > b'psycho-pass'
# > b'k-on-season-2'
# > b'yahari-ore-no-seishun-love-comedy-wa-machigatteiru'
# > b'whisper-of-the-heart'
#
# user_id: 177
# > b'spirited-away'
# > b'spice-and-wolf'
# > b'anohana-the-flower-we-saw-that-day'
# > b'fate-zero'
# > b'clannad-after-story'
#
# user_id: 181
# > b'mahou-shoujo-madoka-magica-movie-1-hajimari-no-monogatari'
# > b'natsume-yuujinchou'
# > b'baccano'
# > b'tengen-toppa-gurren-lagann'
# > b'mahou-shoujo-madoka-magica'
#
# user_id: 184
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'samurai-champloo'
# > b'death-note'
# > b'darker-than-black'
#
# user_id: 180
# > b'neon-genesis-evangelion-the-end-of-evangelion'
# > b'fullmetal-alchemist-brotherhood'
# > b'monster'
# > b'cowboy-bebop'
# > b'log-horizon'
#
# user_id: 183
# > b'ef-a-tale-of-memories'
# > b'ghost-in-the-shell-stand-alone-complex-solid-state-society'
# > b'ef-a-tale-of-melodies'
# > b'monster'
# > b'mobile-suit-gundam-the-08th-ms-team'
#
# user_id: 114
# > b'fullmetal-alchemist'
# > b'darker-than-black'
# > b'angel-beats'
# > b'durarara'
# > b'the-girl-who-leapt-through-time'
#
# user_id: 174
# > b'steins-gate'
# > b'baccano'
# > b'hellsing-ultimate'
# > b'fullmetal-alchemist-brotherhood'
# > b'spirited-away'
#
# user_id: 149
# > b'fate-zero'
# > b'fate-zero-2nd-season'
# > b'monster'
# > b'clannad-after-story'
# > b'ghost-in-the-shell-stand-alone-complex-2nd-gig'
#
# user_id: 185
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'hellsing-ultimate'
# > b'kiki-s-delivery-service'
# > b'zankyou-no-terror'
# > b'chihayafuru-2'
#
# user_id: 165
# > b'kids-on-the-slope'
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'full-metal-panic-fumoffu'
# > b'spice-and-wolf-ii'
# > b'sword-art-online'
#
# user_id: 195
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'hack-sign'
# > b'last-exile'
# > b'fullmetal-alchemist'
#
# user_id: 198
# > b'cowboy-bebop'
# > b'hack-sign'
# > b'last-exile'
# > b'planetes'
# > b'fate-stay-night'
#
# user_id: 171
# > b'samurai-champloo'
# > b'kiki-s-delivery-service'
# > b'wolf-children'
# > b'steins-gate-egoistic-poriomania'
# > b'dragon-ball-z'
#
# user_id: 129
# > b'monster'
# > b'mobile-suit-gundam-unicorn'
# > b'vampire-hunter-d'
# > b'vampire-hunter-d-bloodlust'
# > b'angelic-layer'
#
# user_id: 238
# > b'code-geass-lelouch-of-the-rebellion'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'angel-beats'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
#
# user_id: 216
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
# > b'baccano'
# > b'the-disappearance-of-haruhi-suzumiya'
#
# user_id: 242
# > b'fullmetal-alchemist-brotherhood'
# > b'princess-mononoke'
# > b'steins-gate'
# > b'death-note'
# > b'baccano'
#
# user_id: 243
# > b'fullmetal-alchemist-brotherhood'
# > b'monster'
# > b'great-teacher-onizuka'
# > b'spirited-away'
# > b'nodame-cantabile'
#
# user_id: 272
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'fate-zero-2nd-season'
# > b'steins-gate-egoistic-poriomania'
# > b'monster'
#
# user_id: 274
# > b'steins-gate-egoistic-poriomania'
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'my-neighbor-totoro'
# > b'clannad-after-story'
#
# user_id: 231
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'cowboy-bebop'
# > b'fate-zero-2nd-season'
# > b'monster'
#
# user_id: 222
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'clannad-after-story'
# > b'monster'
# > b'code-geass-lelouch-of-the-rebellion-r2'
#
# user_id: 296
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
# > b'cowboy-bebop'
# > b'baccano'
# > b'fate-zero-2nd-season'
#
# user_id: 263
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'great-teacher-onizuka'
# > b'tengen-toppa-gurren-lagann'
# > b'clannad-after-story'
#
# user_id: 256
# > b'grave-of-the-fireflies'
# > b'darker-than-black'
# > b'wolf-children'
# > b'princess-mononoke'
# > b'mahou-shoujo-madoka-magica-movie-1-hajimari-no-monogatari'
#
# user_id: 236
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'samurai-champloo'
# > b'death-note'
# > b'paprika'
# > b'trigun-badlands-rumble'
#
# user_id: 233
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'last-exile'
# > b'fullmetal-alchemist'
# > b'spirited-away'
# > b'samurai-champloo'
#
# user_id: 218
# > b'welcome-to-the-n-h-k'
# > b'monster'
# > b'steins-gate-egoistic-poriomania'
# > b'chihayafuru-2'
# > b'chihayafuru'
#
# user_id: 246
# > b'baccano'
# > b'the-girl-who-leapt-through-time'
# > b'fate-zero-2nd-season'
# > b'angel-beats'
# > b'fate-zero'
#
# user_id: 254
# > b'angel-beats'
# > b'black-rock-shooter-ova'
# > b'sword-art-online'
# > b'btooom'
# > b'deadman-wonderland'
#
# user_id: 215
# > b'durarara'
# > b'the-girl-who-leapt-through-time'
# > b'steins-gate'
# > b'wolf-children'
# > b'hotarubi-no-mori-e'
#
# user_id: 255
# > b'cowboy-bebop'
# > b'princess-mononoke'
# > b'summer-wars'
# > b'hellsing-ultimate'
# > b'perfect-blue'
#
# user_id: 240
# > b'code-geass-lelouch-of-the-rebellion'
# > b'princess-mononoke'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 203
# > b'fullmetal-alchemist-brotherhood'
# > b'monster'
# > b'perfect-blue'
# > b'princess-mononoke'
# > b'nichijou'
#
# user_id: 258
# > b'steins-gate-egoistic-poriomania'
# > b'spirited-away'
# > b'redline'
# > b'clannad'
# > b'my-neighbor-totoro'
#
# user_id: 225
# > b'howl-s-moving-castle'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'angel-beats'
# > b'the-secret-world-of-arrietty'
# > b'the-girl-who-leapt-through-time'
#
# user_id: 264
# > b'perfect-blue'
# > b'porco-rosso'
# > b'monogatari-series-second-season'
# > b'wolf-children'
# > b'kids-on-the-slope'
#
# user_id: 260
# > b'grave-of-the-fireflies'
# > b'death-note'
# > b'fullmetal-alchemist-brotherhood'
# > b'tengen-toppa-gurren-lagann'
# > b'bakemonogatari'
#
# user_id: 262
# > b'five-centimeters-per-second'
# > b'fullmetal-alchemist-brotherhood'
# > b'spice-and-wolf'
# > b'kids-on-the-slope'
# > b'spice-and-wolf-ii'
#
# user_id: 212
# > b'monster'
# > b'anohana-the-flower-we-saw-that-day'
# > b'steins-gate'
# > b'bakemonogatari'
# > b'hotarubi-no-mori-e'
#
# user_id: 275
# > b'fullmetal-alchemist-brotherhood'
# > b'baccano'
# > b'spirited-away'
# > b'fate-zero-2nd-season'
# > b'clannad-after-story'
#
# user_id: 234
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'the-disappearance-of-haruhi-suzumiya'
# > b'fate-zero'
# > b'angel-beats'
#
# user_id: 251
# > b'code-geass-lelouch-of-the-rebellion'
# > b'the-girl-who-leapt-through-time'
# > b'hotarubi-no-mori-e'
# > b'laputa-castle-in-the-sky'
# > b'samurai-champloo'
#
# user_id: 239
# > b'attack-on-titan'
# > b'tengen-toppa-gurren-lagann'
# > b'evangelion-1-0-you-are-not-alone'
# > b'the-secret-world-of-arrietty'
# > b'wolf-children'
#
# user_id: 241
# > b'cowboy-bebop'
# > b'kiki-s-delivery-service'
# > b'fullmetal-alchemist-brotherhood'
# > b'wolf-children'
# > b'sword-of-the-stranger'
#
# user_id: 227
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'last-exile'
# > b'spirited-away'
#
# user_id: 211
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate-egoistic-poriomania'
# > b'redline'
# > b'clannad-after-story'
# > b'steins-gate'
#
# user_id: 229
# > b'tengen-toppa-gurren-lagann'
# > b'monster'
# > b'rurouni-kenshin-tsuiokuhen'
# > b'berserk'
# > b'porco-rosso'
#
# user_id: 280
# > b'steins-gate-egoistic-poriomania'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'monster'
# > b'nodame-cantabile'
#
# user_id: 245
# > b'perfect-blue'
# > b'one-punch-man'
# > b'wolf-children'
# > b'soul-eater'
# > b'mahou-shoujo-madoka-magica-movie-3-hangyaku-no-monogatari'
#
# user_id: 247
# > b'cowboy-bebop'
# > b'darker-than-black'
# > b'black-lagoon-roberta-s-blood-trail'
# > b'wolf-children'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 205
# > b'baccano'
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'tengen-toppa-gurren-lagann'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 253
# > b'ginga-eiyuu-densetsu'
# > b'monster'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'gankutsuou'
# > b'fate-stay-night-unlimited-blade-works-tv-episode-0'
#
# user_id: 259
# > b'last-exile'
# > b'planetes'
# > b'black-lagoon'
# > b'darker-than-black'
# > b'trigun-badlands-rumble'
#
# user_id: 257
# > b'baccano'
# > b'evangelion-2-0-you-can-not-advance'
# > b'death-note'
# > b'steins-gate-egoistic-poriomania'
# > b'full-metal-panic-fumoffu'
#
# user_id: 288
# > b'darker-than-black'
# > b'kids-on-the-slope'
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'baccano-specials'
#
# user_id: 228
# > b'katanagatari'
# > b'howl-s-moving-castle'
# > b'ghost-in-the-shell'
# > b'ghost-in-the-shell-stand-alone-complex'
# > b'grave-of-the-fireflies'
#
# user_id: 237
# > b'kids-on-the-slope'
# > b'gankutsuou'
# > b'zankyou-no-terror'
# > b'katekyo-hitman-reborn'
# > b'ginga-eiyuu-densetsu'
#
# user_id: 214
# > b'spirited-away'
# > b'porco-rosso'
# > b'my-neighbor-totoro'
# > b'princess-mononoke'
# > b'the-girl-who-leapt-through-time'
#
# user_id: 221
# > b'cowboy-bebop'
# > b'fullmetal-alchemist'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'fullmetal-alchemist-brotherhood'
#
# user_id: 213
# > b'rurouni-kenshin-tsuiokuhen'
# > b'millennium-actress'
# > b'fate-zero-2nd-season'
# > b'gankutsuou'
# > b'ghost-in-the-shell-stand-alone-complex'
#
# user_id: 273
# > b'tengen-toppa-gurren-lagann'
# > b'steins-gate'
# > b'fullmetal-alchemist-brotherhood'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'samurai-champloo'
#
# user_id: 232
# > b'steins-gate'
# > b'spice-and-wolf'
# > b'perfect-blue'
# > b'fate-zero'
# > b'fate-zero-2nd-season'
#
# user_id: 285
# > b'cowboy-bebop'
# > b'kill-la-kill'
# > b'summer-wars'
# > b'bakuman-3'
# > b'boku-no-hero-academia-2nd-season'
#
# user_id: 281
# > b'steins-gate-egoistic-poriomania'
# > b'baccano'
# > b'fullmetal-alchemist-brotherhood'
# > b'steins-gate'
# > b'fate-zero'
#
# user_id: 298
# > b'baccano'
# > b'hotarubi-no-mori-e'
# > b'clannad-after-story'
# > b'fate-zero-2nd-season'
# > b'the-disappearance-of-haruhi-suzumiya'
#
# user_id: 250
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'fullmetal-alchemist'
# > b'spirited-away'
# > b'samurai-champloo'
# > b'kiki-s-delivery-service'
#
# user_id: 244
# > b'ginga-eiyuu-densetsu'
# > b'gankutsuou'
# > b'fullmetal-alchemist-the-conqueror-of-shamballa'
# > b'gintama'
# > b'cowboy-bebop'
#
# user_id: 293
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'samurai-champloo'
# > b'my-neighbor-totoro'
# > b'death-note'
# > b'trigun-badlands-rumble'
#
# user_id: 278
# > b'cowboy-bebop'
# > b'samurai-champloo'
# > b'code-geass-lelouch-of-the-rebellion'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'princess-mononoke'
#
# user_id: 248
# > b'cowboy-bebop'
# > b'last-exile'
# > b'spirited-away'
# > b'samurai-champloo'
# > b'planetes'
#
# user_id: 235
# > b'howl-s-moving-castle'
# > b'trigun'
# > b'grave-of-the-fireflies'
# > b'evangelion-1-0-you-are-not-alone'
# > b'evangelion-2-0-you-can-not-advance'
#
# user_id: 286
# > b'howl-s-moving-castle'
# > b'steins-gate'
# > b'danshi-koukousei-no-nichijou'
# > b'katanagatari'
# > b'nekomonogatari-kuro'
#
# user_id: 295
# > b'fullmetal-alchemist-brotherhood'
# > b'shinsekai-yori'
# > b'steins-gate'
# > b'clannad-after-story'
# > b'neon-genesis-evangelion'
#
# user_id: 292
# > b'fullmetal-alchemist'
# > b'samurai-champloo'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'black-lagoon-roberta-s-blood-trail'
# > b'sword-art-online'
#
# user_id: 265
# > b'last-exile'
# > b'howl-s-moving-castle'
# > b'black-lagoon-the-second-barrage'
# > b'code-geass-lelouch-of-the-rebellion-r2'
# > b'black-lagoon-roberta-s-blood-trail'
#
# user_id: 279
# > b'mirai-nikki-tv'
# > b'eve-no-jikan-movie'
# > b'nausicaa-of-the-valley-of-the-wind'
# > b'black-lagoon'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 289
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'beck'
# > b'last-exile'
# > b'samurai-champloo'
# > b'planetes'
#
# user_id: 276
# > b'fullmetal-alchemist'
# > b'fate-stay-night'
# > b'black-lagoon-roberta-s-blood-trail'
# > b'fractale'
# > b'fullmetal-alchemist-brotherhood'
#
# user_id: 294
# > b'beck'
# > b'macross-zero'
# > b'ergo-proxy'
# > b'angel-beats'
# > b'steins-gate-egoistic-poriomania'
#
# user_id: 287
# > b'fullmetal-alchemist'
# > b'samurai-champloo'
# > b'laputa-castle-in-the-sky'
# > b'rec'
# > b'ergo-proxy'
#
# user_id: 291
# > b'full-metal-panic-the-second-raid'
# > b'baccano'
# > b'steins-gate-egoistic-poriomania'
# > b'ghost-in-the-shell'
# > b'spice-and-wolf-ii-specials'
#
# user_id: 282
# > b'fullmetal-alchemist'
# > b'kiki-s-delivery-service'
# > b'digimon-adventure'
# > b'dragon-ball'
# > b'rurouni-kenshin-tsuiokuhen'
#
# user_id: 268
# > b'death-note'
# > b'monster'
# > b'fullmetal-alchemist-brotherhood'
# > b'samurai-champloo'
# > b'the-disappearance-of-haruhi-suzumiya'
#
# user_id: 299
# > b'cowboy-bebop'
# > b'cowboy-bebop-tengoku-no-tobira'
# > b'pale-cocoon'
# > b'black-lagoon'
# > b'black-lagoon-the-second-barrage'
#
# user_id: 269
# > b'howl-s-moving-castle'
# > b'princess-mononoke'
# > b'fullmetal-alchemist-brotherhood'
# > b'perfect-blue'
# > b'monogatari-series-second-season'
#
# user_id: 271
# > b'ginga-eiyuu-densetsu'
# > b'gosick'
# > b'eve-no-jikan-movie'
# > b'hajime-no-ippo'
# > b'hunter-x-hunter'
#
# user_id: 201
# > b'monster'
# > b'hajime-no-ippo'
# > b'full-metal-panic-the-second-raid'
# > b'millennium-actress'
# > b'full-metal-panic-fumoffu'

# %%
collection = client.kitsu.library
cursor = collection.find(
    {"user_id": 7, "rating": {"$ne": None}},
    {'user_id': 1, 'media_id': 1, '_id': 0}
)

for i, doc in enumerate(cursor):
    x = encode_dict(doc)
    print(id_slug_map[x['media_id']])
# Out:
# b'cowboy-bebop'
# b'cowboy-bebop-tengoku-no-tobira'
# b'hack-sign'
# b'beck'
# b'rozen-maiden'
# b'shuffle'
# b'last-exile'
# b'mai-hime'
# b'fullmetal-alchemist'
# b'gunslinger-girl'
# b'macross-zero'
# b'spirited-away'
# b'samurai-champloo'
# b'planetes'
# b'fate-stay-night'
# b'boogiepop-phantom'
# b'porco-rosso'
# b'howl-s-moving-castle'
# b'karin'
# b'kiki-s-delivery-service'
# b'laputa-castle-in-the-sky'
# b'metropolis'
# b'my-neighbor-totoro'
# b'the-cat-returns'
# b'rec'
# b'pale-cocoon'
# b'ergo-proxy'
# b'air-gear'
# b'black-lagoon'
# b'kanojo-to-kanojo-no-neko'
# b'pom-poko'
# b'black-lagoon-the-second-barrage'
# b'death-note'
# b'code-geass-lelouch-of-the-rebellion'
# b'rozen-maiden-ouverture'
# b'paprika'
# b'darker-than-black'
# b'code-geass-lelouch-of-the-rebellion-r2'
# b'appleseed-saga-ex-machina'
# b'trigun-badlands-rumble'
# b'black-lagoon-roberta-s-blood-trail'
# b'eden-of-the-east'
# b'eden-of-the-east-movie-i-the-king-of-eden'
# b'eden-of-the-east-falling-down'
# b'angel-beats'
# b'eden-of-the-east-movie-ii-paradise-lost'
# b'durarara'
# b'black-rock-shooter-ova'
# b'the-secret-world-of-arrietty'
# b'air-gear-kuro-no-hane-to-nemuri-no-mori-break-on-the-sky'
# b'fractale'
# b'mirai-nikki-tv'
# b'sword-art-online'
